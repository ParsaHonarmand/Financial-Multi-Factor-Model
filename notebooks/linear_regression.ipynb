# %% [markdown]
# # Linear Regression
#
# The notebook below demonstrates running the Financial Model against 100 stocks in the S&P 500.

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import os
import bs4 as bs
import requests
import random
import datetime

def add_stocks_from_tickers(tickers: list[str], **kwargs: dict[str, str]) -> pd.DataFrame:
    """ Takes a stock ticker string, calculates the returns, and inserts them into a data frame

    #fetching-data-for-multiple-tickers to see how they work.
    Takes optional period and interval keyword args. Go to https://github.com/ranaroussi/yfinance
    """

    joint_stock_df = pd.DataFrame()
    date = datetime.datetime(2014,1,3,0,0,0)
    for ticker in tickers: 
        close_prices = yf.download(ticker, start="2014-01-03", end="2021-12-01", interval=kwargs.get(
            'interval', "1d"))[['Close']].dropna()
        try:
            print(close_prices.loc[date])
            close_prices = close_prices.rename(columns={'Close':f'{ticker}'})
            if joint_stock_df.empty:
                joint_stock_df = close_prices
            else:
                joint_stock_df =joint_stock_df.join(close_prices,on='Date', how='left', lsuffix='_left', rsuffix='_right')
        except KeyError:
            print(f'Could not add {ticker}')

    return joint_stock_df.apply(lambda ticker: get_returns(ticker))


def get_returns(close_prices: pd.DataFrame) -> pd.DataFrame:
    """Takes a datafrom of closing prices, calculates the returns, and returns them as a dataframe"""
    offset_close = close_prices.shift(-1)
    offset_returns = offset_close / close_prices - 1
    return offset_returns.shift(1).dropna()


def add_factors_from_tickers(factors: list[str], **kwargs: dict[str, str]):
    """Takes a factor name (for better printing), a ticker representing a factor (such as a thematic index ticker) and the same kwargs as the constructor"""
    return add_stocks_from_tickers(factors, **kwargs)

def split_data(df: pd.DataFrame, ratio = 0.7) -> tuple[pd.DataFrame, pd.DataFrame]:
  return df.iloc[:int(ratio*len(df))], df.iloc[int(ratio*len(df)):]

def test_model(model: sm.OLS, factor_test_df: pd.DataFrame, stock_test_df: pd.Series, plot = False, debug = False) -> tuple[pd.DataFrame, float]:
    """ Function calculates the series of predictions with the calculated model, then joins the series to the stock's dataframe and calculates the squared error
    """
    prediction: pd.Series = model.predict(factor_test_df)

    prediction_and_actual = prediction.to_frame('Prediction').join(stock_test_df, on='Date', how='left', lsuffix='_left', rsuffix='_right')

    prediction_and_actual['squared_error'] = (prediction_and_actual[stock_test_df.name] - prediction_and_actual['Prediction']) ** 2

    if debug: print(prediction_and_actual)

    mse = prediction_and_actual['squared_error'].sum() / prediction.size
    

    if plot:
        prediction_and_actual.plot()
        plt.show()
    
    return (prediction_and_actual, mse)

def test_regularized_model(model: sm.OLS, test_alpha, stock_test_df: pd.DataFrame, factor_test_df:pd.DataFrame) -> tuple[pd.DataFrame, float] :
    """We can check a stock's alpha response change by just changing the test alpha passed in.
    Function makes a regularized model with a ridge method (minimization of summation is squared errors)
    """ 

    reg_results = model.fit_regularized(method = 'elastic_net', alpha = test_alpha, L1_wt=0)
    prediction_df, new_mse = test_model(reg_results, factor_test_df, stock_test_df)
    print(f"Final alpha value used: {test_alpha}")

    return (prediction_df, new_mse)

def add_to_output_files(ticker, df_to_append: pd.DataFrame, regularization_check = False):
    """"Takes in the prediction data frame to append as a tab to an excel file. If the file does not exist, it creates it. 
    Creates different files for regularized linear regression results and basic regression results
    """
    
    if regularization_check:
        filename = 'outputReg4.xlsx'
    else:
        filename = 'output4.xlsx'
    
    if(os.path.isfile(filename)):
        with pd.ExcelWriter(filename, mode = 'a') as writer:
            df_to_append.to_excel(writer, sheet_name=f'{ticker}')
    else:
        df_to_append.to_excel(filename, sheet_name=f'{ticker}')

    


def regress_factors(stocks_df: pd.DataFrame, factors_df: pd.DataFrame, signif_level = 0.05, r2_threshold = 0.65):
    """Takes a list of factors that you want to regress on and will print a summary of a multiple regression on those factors with the objects stock

    Can pass in self.factor_names to regress on all factors
    """
    factors_df = sm.add_constant(factors_df)
    factor_train_df, factor_test_df = split_data(factors_df)

    portfolios = dict()
    for stock in stocks_df:
        stock_train_df, stock_test_df = split_data(stocks_df[stock])
        pvals_under_sig = False
        temp_factor_df: pd.DataFrame = factor_train_df
    
        while(not(pvals_under_sig) and (len(temp_factor_df.columns)>0)):

            ticker = stock[1] if isinstance(stock, tuple) else stock
            model = sm.OLS(stock_train_df, temp_factor_df)
            results = model.fit()

            factor_pvals = zip(results.pvalues.index, results.pvalues.values)
            all_pvals_under = True
            
            for factor_pval in factor_pvals:
                factor, pvalue = factor_pval
                if pvalue > signif_level and factor != 'const':
                    all_pvals_under = False
                    temp_factor_df = temp_factor_df.drop(columns=factor, axis = 1)

            if results.rsquared_adj >= r2_threshold and all_pvals_under:
                if (portfolios.get(str(factor))) is None:
                    portfolios[str(factor)] = set([ticker])
                else:
                    portfolios[str(factor)].add(ticker)
 
                to_remove = [col for col in factor_test_df.columns if col not in temp_factor_df.columns]
                factor_test_temp_df = factor_test_df.drop(to_remove, axis=1)
                prediction_df, mse = test_model(results, factor_test_temp_df, stock_test_df)
                reg_prediction_df, reg_mse = test_regularized_model(model, 0.01, stock_test_df, factor_test_temp_df)
                print(f"Prediction Mean Squared Error: {mse}")  
                print(f"Regularized Prediction Mean Squared Error: {reg_mse}")
                print(results.summary())

            if all_pvals_under:
                pvals_under_sig = True

    return portfolios

def debug_shape(dfs: list[pd.DataFrame]):
    for df in dfs:
        print(df.shape)

def add_factors_from_csv(directory) -> pd.DataFrame:
    """Takes a factor name and a CSV file, calculates the returns and returns them as a dataframe
    The first two elements should be a date column heading and a "Close" (case sensitive) column heading. 
    The data should be two columns corresponding to dates and closing prices. 
    This method is untested and may need to be modified.
    """
    factorlist: pd.DataFrame = []
    for file in os.listdir(directory):
        filepath = directory + file
        factor_close = pd.read_csv(filepath, index_col=0, parse_dates=['Date'])

        factorlist.append(factor_close)

    combined_factors: pd.DataFrame = factorlist[0]
    for i in range(1, len(factorlist)):
        df = factorlist[i]
        combined_factors = combined_factors.join(df, on='Date', how='left', lsuffix='_left', rsuffix='_right')

    return combined_factors.apply(lambda factor: get_returns(factor))


def normalize_factor_dates(stock_factors: pd.DataFrame) -> pd.DataFrame:
    temp_stock = add_stocks_from_tickers(['MSFT'])
    return temp_stock.join(stock_factors, on='Date', how='left', lsuffix='_left', rsuffix='_right') \
        .drop('MSFT', axis=1)


# Retrieving a list of all of the stocks in the S&P 500 index and putting them in a list
def save_sp500_tickers():
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        ticker = ticker.replace('\n', '')
        tickers.append(ticker)    
  
    return tickers

def get_n_random_stocks(num):
    randlist = []
    numStocksToAnalyze =num
    i = 0
    while (i < numStocksToAnalyze):
        r = random.randint(0,499)
        if r not in randlist:
            randlist.append(r) 
            i+=1
    
    stock_list = save_sp500_tickers()
    stocks_to_analyze = []
    for i in randlist:
        stocks_to_analyze.append(stock_list[i])
    
    return stocks_to_analyze
    

if __name__ == '__main__':
    stocks_to_analyze = get_n_random_stocks(100)

    stocks = add_stocks_from_tickers(stocks_to_analyze)
    factors = add_factors_from_csv('factorDirectory/')

    normalizedFactors = normalize_factor_dates(factors)

    for column in normalizedFactors.columns:
        if column == 'Close':
            normalizedFactors = normalizedFactors.drop(columns=column, axis = 1)

    portfolios = regress_factors(stocks, normalizedFactors)
    print(portfolios)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Close    41.52
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    17.82
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    40.619999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    37.720001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    151.050003
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    21.09
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    137.619995
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    61.029999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    32.279999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add HPE
# [*********************100%***********************]  1 of 1 completed
# Close    14.06
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add ANET
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
# Could not add BF.B
# [*********************100%***********************]  1 of 1 completed
# Close    81.510002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    48.959999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    117.290001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    21.747499
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    39.779999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    36.93
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    22.809999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    92.849998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    47.385639
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    55.18
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    103.919998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    113.900002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add OGN
# [*********************100%***********************]  1 of 1 completed
# Close    74.32
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add IR
# [*********************100%***********************]  1 of 1 completed
# Close    102.290001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    59.16
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    53.049999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    45.619999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    36.119999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    49.753143
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    73.449997
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    25.344999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    100.047935
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    32.755001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    47.571762
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    148.190002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    47.169998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    11.21
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    20.34
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    48.650002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    90.769997
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    15.16
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    83.425003
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    73.730003
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    27.719999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    28.956356
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    40.330002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    108.760002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add FOX
# [*********************100%***********************]  1 of 1 completed
# Close    41.495556
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    23.370001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    57.34
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    35.970001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    104.110001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    82.599998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    9.476667
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    34.799999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    49.830002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    58.34
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    13.32
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    65.530197
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    91.849998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    55.299999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    50.919998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    12.870118
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    51.871429
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    34.57
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    46.580002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    53.459999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add WRK
# [*********************100%***********************]  1 of 1 completed
# Close    76.959999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add CTVA
# [*********************100%***********************]  1 of 1 completed
# Close    53.59
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    42.09
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    1132.680054
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    33.669998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    51.57
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    140.050003
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    89.160004
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    53.330002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    144.825958
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    43.959999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    75.099998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    49.259998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    54.560001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    28.66
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    89.5979
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    60.933334
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    64.850975
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    110.050003
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    88.349998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    72.889999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    46.16
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    55.009998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    20.92
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add CFG
# [*********************100%***********************]  1 of 1 completed
# Close    36.91
# Name: 2014-01-03 00:00:00, dtype: float64
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00011096309136193552
# Regularized Prediction Mean Squared Error: 0.0004128791906154271
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ES   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.660
# Method:                 Least Squares   F-statistic:                     452.2
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          4.59e-322
# Time:                        21:37:35   Log-Likelihood:                 5136.2
# No. Observations:                1393   AIC:                        -1.026e+04
# Df Residuals:                    1386   BIC:                        -1.022e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                 1.702e-05      0.000      0.104      0.917      -0.000       0.000
# Dow Jones U.S. Thematic Long Size Total Return Index    -0.2122      0.053     -3.991      0.000      -0.317      -0.108
# S&P 500 ESG Enhanced Value Index (USD) TR               -0.3688      0.082     -4.513      0.000      -0.529      -0.208
# S&P 500 Volatility - Highest Quintile Index TR          -0.1350      0.039     -3.483      0.001      -0.211      -0.059
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR          1.6213      0.035     46.727      0.000       1.553       1.689
# S&P 500 Pure Growth (TR)                                -0.2207      0.043     -5.149      0.000      -0.305      -0.137
# S&P 500 Pure Value (TR)                                  0.2958      0.071      4.156      0.000       0.156       0.435
# ==============================================================================
# Omnibus:                      127.555   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              822.822
# Skew:                           0.046   Prob(JB):                    2.12e-179
# Kurtosis:                       6.764   Cond. No.                         646.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00015343263743528197
# Regularized Prediction Mean Squared Error: 0.0008393232384932938
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    PFG   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     640.4
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        21:37:35   Log-Likelihood:                 4685.4
# No. Observations:                1393   AIC:                            -9359.
# Df Residuals:                    1387   BIC:                            -9327.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                               -0.0003      0.000     -1.140      0.254      -0.001       0.000
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     1.3187      0.075     17.667      0.000       1.172       1.465
# S&P 500 Volatility - Highest Quintile Index TR      -0.7700      0.053    -14.479      0.000      -0.874      -0.666
# S&P 500 Low Rate-Sensitivity Index (USD) TR          1.7200      0.258      6.658      0.000       1.213       2.227
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR     -0.6723      0.143     -4.692      0.000      -0.953      -0.391
# S&P 500 Pure Growth (TR)                            -0.3429      0.070     -4.880      0.000      -0.481      -0.205
# ==============================================================================
# Omnibus:                      208.389   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2445.396
# Skew:                          -0.254   Prob(JB):                         0.00
# Kurtosis:                       9.471   Cond. No.                     1.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00016133368053493978
# Regularized Prediction Mean Squared Error: 0.0008566230945896635
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    TFC   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     679.3
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        21:37:35   Log-Likelihood:                 4862.7
# No. Observations:                1393   AIC:                            -9715.
# Df Residuals:                    1388   BIC:                            -9689.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                            -1.357e-05      0.000     -0.068      0.945      -0.000       0.000
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     1.5103      0.051     29.587      0.000       1.410       1.610
# S&P 500 Volatility - Highest Quintile Index TR      -0.8065      0.046    -17.602      0.000      -0.896      -0.717
# S&P 500 Quality - Lowest Quintile Index TR           0.4192      0.072      5.843      0.000       0.278       0.560
# S&P 500 Pure Growth (TR)                            -0.2810      0.054     -5.160      0.000      -0.388      -0.174
# ==============================================================================
# Omnibus:                      141.489   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1044.796
# Skew:                          -0.060   Prob(JB):                    1.33e-227
# Kurtosis:                       7.241   Cond. No.                         440.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.000174375634579803
# Regularized Prediction Mean Squared Error: 0.0009075461244970187
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    AMP   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.684
# Method:                 Least Squares   F-statistic:                     752.8
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        21:37:35   Log-Likelihood:                 4571.4
# No. Observations:                1393   AIC:                            -9133.
# Df Residuals:                    1388   BIC:                            -9107.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                               -0.0002      0.000     -0.759      0.448      -0.001       0.000
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     1.2084      0.077     15.777      0.000       1.058       1.359
# S&P 500 Volatility - Highest Quintile Index TR      -0.6623      0.058    -11.480      0.000      -0.775      -0.549
# S&P 500 Low Rate-Sensitivity Index (USD) TR          1.5006      0.195      7.698      0.000       1.118       1.883
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR     -0.8161      0.128     -6.359      0.000      -1.068      -0.564
# ==============================================================================
# Omnibus:                      386.439   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11458.276
# Skew:                           0.648   Prob(JB):                         0.00
# Kurtosis:                      16.991   Cond. No.                         972.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 8.111322259173521e-05
# Regularized Prediction Mean Squared Error: 0.0003097731212792726
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    LNT   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     422.4
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        21:37:35   Log-Likelihood:                 5154.6
# No. Observations:                1393   AIC:                        -1.029e+04
# Df Residuals:                    1385   BIC:                        -1.025e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                 5.074e-05      0.000      0.315      0.753      -0.000       0.000
# Dow Jones U.S. High Momentum Total Return Index          0.1658      0.066      2.505      0.012       0.036       0.296
# Dow Jones U.S. Thematic Long Size Total Return Index    -0.1717      0.058     -2.975      0.003      -0.285      -0.058
# S&P 500 ESG Enhanced Value Index (USD) TR               -0.4940      0.081     -6.061      0.000      -0.654      -0.334
# S&P 500 Volatility - Highest Quintile Index TR          -0.1252      0.039     -3.212      0.001      -0.202      -0.049
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR          1.6432      0.034     47.748      0.000       1.576       1.711
# S&P 500 Pure Growth (TR)                                -0.2885      0.065     -4.432      0.000      -0.416      -0.161
# S&P 500 Pure Value (TR)                                  0.2994      0.071      4.223      0.000       0.160       0.439
# ==============================================================================
# Omnibus:                      176.710   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1241.405
# Skew:                           0.350   Prob(JB):                    2.71e-270
# Kurtosis:                       7.571   Cond. No.                         693.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00018782363792214783
# Regularized Prediction Mean Squared Error: 0.0010891697663367695
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    KEY   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     401.4
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        21:37:36   Log-Likelihood:                 4547.5
# No. Observations:                1393   AIC:                            -9079.
# Df Residuals:                    1385   BIC:                            -9037.
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                             1.215e-05      0.000      0.049      0.961      -0.000       0.001
# Dow Jones U.S. High Momentum Total Return Index      0.4028      0.094      4.287      0.000       0.219       0.587
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     1.6685      0.096     17.430      0.000       1.481       1.856
# S&P 500 Volatility - Highest Quintile Index TR      -0.9482      0.059    -16.016      0.000      -1.064      -0.832
# S&P 500 Low Rate-Sensitivity Index (USD) TR         -0.7347      0.137     -5.375      0.000      -1.003      -0.467
# S&P 500 Quality - Lowest Quintile Index TR           0.3880      0.105      3.698      0.000       0.182       0.594
# S&P 500 Pure Growth (TR)                            -0.2615      0.108     -2.423      0.016      -0.473      -0.050
# S&P 500 Pure Value (TR)                              0.4194      0.122      3.442      0.001       0.180       0.658
# ==============================================================================
# Omnibus:                      172.403   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1699.201
# Skew:                           0.095   Prob(JB):                         0.00
# Kurtosis:                       8.407   Cond. No.                         746.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00011874724118550183
# Regularized Prediction Mean Squared Error: 0.000659602030945122
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    PNC   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     812.0
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        21:37:36   Log-Likelihood:                 4944.2
# No. Observations:                1393   AIC:                            -9878.
# Df Residuals:                    1388   BIC:                            -9852.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                                0.0002      0.000      0.862      0.389      -0.000       0.001
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     1.5791      0.048     32.799      0.000       1.485       1.674
# S&P 500 Volatility - Highest Quintile Index TR      -0.8764      0.043    -20.281      0.000      -0.961      -0.792
# S&P 500 Quality - Lowest Quintile Index TR           0.3067      0.068      4.532      0.000       0.174       0.439
# S&P 500 Pure Growth (TR)                            -0.1385      0.051     -2.697      0.007      -0.239      -0.038
# ==============================================================================
# Omnibus:                      224.996   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1269.963
# Skew:                          -0.621   Prob(JB):                    1.70e-276
# Kurtosis:                       7.510   Cond. No.                         440.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# {'S&P 500 Pure Value (TR)': {'LNT', 'ES', 'KEY'}, 'S&P 500 Pure Growth (TR)': {'PFG', 'TFC', 'PNC'}, 'S&P 500 Low Rate-Sensitivity 100 Index (USD) TR': {'AMP'}}

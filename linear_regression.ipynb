# %% [markdown]
# # Linear Regression
#
# Here is a non-parallized version of our linear regression code. We have submitted another notebook which shows the following code taking advantage of parallelization provided through Apache Spark. We chose to use 50 stocks in this implementation because they take too long to download. We have paralellized this operation in our Spark version, which uses 300 stocks.

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import os
import bs4 as bs
import requests
import random
import datetime

def add_stocks_from_tickers(tickers: list[str], **kwargs: dict[str, str]) -> pd.DataFrame:
    """ Takes a stock ticker string, calculates the returns, and inserts them into a data frame

    #fetching-data-for-multiple-tickers to see how they work.
    Takes optional period and interval keyword args. Go to https://github.com/ranaroussi/yfinance
    """

    joint_stock_df = pd.DataFrame()
    date = datetime.datetime(2014,1,3,0,0,0)
    for ticker in tickers: 
        close_prices = yf.download(ticker, start="2014-01-03", end="2021-12-01", interval=kwargs.get(
            'interval', "1d"))[['Close']].dropna()
        try:
            print(close_prices.loc[date])
            close_prices = close_prices.rename(columns={'Close':f'{ticker}'})
            if joint_stock_df.empty:
                joint_stock_df = close_prices
            else:
                joint_stock_df =joint_stock_df.join(close_prices,on='Date', how='left', lsuffix='_left', rsuffix='_right')
        except KeyError:
            print(f'Could not add {ticker}')

    return joint_stock_df.apply(lambda ticker: get_returns(ticker))


def get_returns(close_prices: pd.DataFrame) -> pd.DataFrame:
    """Takes a datafrom of closing prices, calculates the returns, and returns them as a dataframe"""
    offset_close = close_prices.shift(-1)
    offset_returns = offset_close / close_prices - 1
    return offset_returns.shift(1).dropna()


def add_factors_from_tickers(factors: list[str], **kwargs: dict[str, str]):
    """Takes a factor name (for better printing), a ticker representing a factor (such as a thematic index ticker) and the same kwargs as the constructor"""
    return add_stocks_from_tickers(factors, **kwargs)

def split_data(df: pd.DataFrame, ratio = 0.7) -> tuple[pd.DataFrame, pd.DataFrame]:
  return df.iloc[:int(ratio*len(df))], df.iloc[int(ratio*len(df)):]

def test_model(model: sm.OLS, factor_test_df: pd.DataFrame, stock_test_df: pd.Series, plot = False, debug = False) -> tuple[pd.DataFrame, float]:
    """ Function calculates the series of predictions with the calculated model, then joins the series to the stock's dataframe and calculates the squared error
    """
    prediction: pd.Series = model.predict(factor_test_df)

    prediction_and_actual = prediction.to_frame('Prediction').join(stock_test_df, on='Date', how='left', lsuffix='_left', rsuffix='_right')

    prediction_and_actual['squared_error'] = (prediction_and_actual[stock_test_df.name] - prediction_and_actual['Prediction']) ** 2

    if debug: print(prediction_and_actual)

    mse = prediction_and_actual['squared_error'].sum() / prediction.size
    

    if plot:
        prediction_and_actual.plot()
        plt.show()
    
    return (prediction_and_actual, mse)

def test_regularized_model(model: sm.OLS, test_alpha, stock_test_df: pd.DataFrame, factor_test_df:pd.DataFrame) -> tuple[pd.DataFrame, float] :
    """We can check a stock's alpha response change by just changing the test alpha passed in.
    Function makes a regularized model with a ridge method (minimization of summation is squared errors)
    """ 

    reg_results = model.fit_regularized(method = 'elastic_net', alpha = test_alpha, L1_wt=0)
    prediction_df, new_mse = test_model(reg_results, factor_test_df, stock_test_df)
    print(f"Final alpha value used: {test_alpha}")

    return (prediction_df, new_mse)

def add_to_output_files(ticker, df_to_append: pd.DataFrame, regularization_check = False):
    """"Takes in the prediction data frame to append as a tab to an excel file. If the file does not exist, it creates it. 
    Creates different files for regularized linear regression results and basic regression results
    """
    
    if regularization_check:
        filename = 'outputReg4.xlsx'
    else:
        filename = 'output4.xlsx'
    
    if(os.path.isfile(filename)):
        with pd.ExcelWriter(filename, mode = 'a') as writer:
            df_to_append.to_excel(writer, sheet_name=f'{ticker}')
    else:
        df_to_append.to_excel(filename, sheet_name=f'{ticker}')

    


def regress_factors(stocks_df: pd.DataFrame, factors_df: pd.DataFrame, signif_level = 0.05, r2_threshold = 0.5):
    """Takes a list of factors that you want to regress on and will print a summary of a multiple regression on those factors with the objects stock

    Can pass in self.factor_names to regress on all factors
    """
    factors_df = sm.add_constant(factors_df)
    factor_train_df, factor_test_df = split_data(factors_df)

    portfolios = dict()
    for stock in stocks_df:
        stock_train_df, stock_test_df = split_data(stocks_df[stock])
        pvals_under_sig = False
        temp_factor_df: pd.DataFrame = factor_train_df
    
        while(not(pvals_under_sig) and (len(temp_factor_df.columns)>0)):

            ticker = stock[1] if isinstance(stock, tuple) else stock
            model = sm.OLS(stock_train_df, temp_factor_df)
            results = model.fit()

            factor_pvals = zip(results.pvalues.index, results.pvalues.values)
            all_pvals_under = True
            
            for factor_pval in factor_pvals:
                factor, pvalue = factor_pval
                if pvalue > signif_level and factor != 'const':
                    all_pvals_under = False
                    temp_factor_df = temp_factor_df.drop(columns=factor, axis = 1)

            if results.rsquared_adj >= r2_threshold and all_pvals_under:
                if (portfolios.get(str(factor))) is None:
                    portfolios[str(factor)] = set([ticker])
                else:
                    portfolios[str(factor)].add(ticker)
 
                to_remove = [col for col in factor_test_df.columns if col not in temp_factor_df.columns]
                factor_test_temp_df = factor_test_df.drop(to_remove, axis=1)
                prediction_df, mse = test_model(results, factor_test_temp_df, stock_test_df)
                reg_prediction_df, reg_mse = test_regularized_model(model, 0.01, stock_test_df, factor_test_temp_df)
                print(f"Prediction Mean Squared Error: {mse}")  
                print(f"Regularized Prediction Mean Squared Error: {reg_mse}")
                print(results.summary())

            if all_pvals_under:
                pvals_under_sig = True

    return portfolios

def debug_shape(dfs: list[pd.DataFrame]):
    for df in dfs:
        print(df.shape)

def add_factors_from_csv(directory) -> pd.DataFrame:
    """Takes a factor name and a CSV file, calculates the returns and returns them as a dataframe
    The first two elements should be a date column heading and a "Close" (case sensitive) column heading. 
    The data should be two columns corresponding to dates and closing prices. 
    This method is untested and may need to be modified.
    """
    factorlist: pd.DataFrame = []
    for file in os.listdir(directory):
        filepath = directory + file
        factor_close = pd.read_csv(filepath, index_col=0, parse_dates=['Date'])

        factorlist.append(factor_close)

    combined_factors: pd.DataFrame = factorlist[0]
    for i in range(1, len(factorlist)):
        df = factorlist[i]
        combined_factors = combined_factors.join(df, on='Date', how='left', lsuffix='_left', rsuffix='_right')

    return combined_factors.apply(lambda factor: get_returns(factor))


def normalize_factor_dates(stock_factors: pd.DataFrame) -> pd.DataFrame:
    temp_stock = add_stocks_from_tickers(['MSFT'])
    return temp_stock.join(stock_factors, on='Date', how='left', lsuffix='_left', rsuffix='_right') \
        .drop('MSFT', axis=1)


# Retrieving a list of all of the stocks in the S&P 500 index and putting them in a list
def save_sp500_tickers():
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        ticker = ticker.replace('\n', '')
        tickers.append(ticker)    
  
    return tickers

def get_n_random_stocks(num):
    randlist = []
    numStocksToAnalyze =num
    i = 0
    while (i < numStocksToAnalyze):
        r = random.randint(0,499)
        if r not in randlist:
            randlist.append(r) 
            i+=1
    
    stock_list = save_sp500_tickers()
    stocks_to_analyze = []
    for i in randlist:
        stocks_to_analyze.append(stock_list[i])
    
    return stocks_to_analyze
    

if __name__ == '__main__':
    stocks_to_analyze = get_n_random_stocks(50)

    stocks = add_stocks_from_tickers(stocks_to_analyze)
    factors = add_factors_from_csv('factorDirectory/')

    normalizedFactors = normalize_factor_dates(factors)

    for column in normalizedFactors.columns:
        if column == 'Close':
            normalizedFactors = normalizedFactors.drop(columns=column, axis = 1)

    portfolios = regress_factors(stocks, normalizedFactors)
    print(portfolios)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Close    73.650002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    44.189999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    119.760002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    48.900002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    17.559999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    63.509998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    51.871429
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    46.110001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    96.540001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    94.739998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    550.436829
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    4.0
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    22.190001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    40.68
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    52.43
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    160.710007
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    56.82
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    60.98
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    51.66
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    69.300003
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    45.16452
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add HPE
# [*********************100%***********************]  1 of 1 completed
# Close    32.950821
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    48.419998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    22.68
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    63.490002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add WRK
# [*********************100%***********************]  1 of 1 completed
# Close    63.139999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add FOX
# [*********************100%***********************]  1 of 1 completed
# Close    58.59
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add ANET
# [*********************100%***********************]  1 of 1 completed
# Close    53.150002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    78.650002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    99.510002
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Could not add SYF
# [*********************100%***********************]  1 of 1 completed
# Close    50.799999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    85.919998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    37.165001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    58.98
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    61.299999
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    23.450001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    40.060001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    76.480003
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    43.560001
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    14.06
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    52.169998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    17.82
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    28.956356
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    553.05304
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    95.809998
# Name: 2014-01-03 00:00:00, dtype: float64
# [*********************100%***********************]  1 of 1 completed
# Close    36.91
# Name: 2014-01-03 00:00:00, dtype: float64
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00019590914039777568
# Regularized Prediction Mean Squared Error: 0.00048427319040360577
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    AVB   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     242.1
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          1.15e-211
# Time:                        20:08:39   Log-Likelihood:                 4866.3
# No. Observations:                1393   AIC:                            -9719.
# Df Residuals:                    1386   BIC:                            -9682.
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                            -1.765e-06      0.000     -0.009      0.993      -0.000       0.000
# S&P 500 ESG Quality Index (USD) TR                  -0.4646      0.106     -4.378      0.000      -0.673      -0.256
# S&P 500 ESG Enhanced Value Index (USD) TR            0.3284      0.130      2.532      0.011       0.074       0.583
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     0.3222      0.080      4.050      0.000       0.166       0.478
# S&P 500 Volatility - Highest Quintile Index TR      -0.2386      0.046     -5.207      0.000      -0.328      -0.149
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR      1.3564      0.052     26.100      0.000       1.254       1.458
# S&P 500 Pure Value (TR)                             -0.3041      0.091     -3.350      0.001      -0.482      -0.126
# ==============================================================================
# Omnibus:                      109.329   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              343.218
# Skew:                          -0.367   Prob(JB):                     2.96e-75
# Kurtosis:                       5.319   Cond. No.                         820.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00011679818817853889
# Regularized Prediction Mean Squared Error: 0.0004001185457689271
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      D   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     275.9
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          2.12e-232
# Time:                        20:08:40   Log-Likelihood:                 4935.3
# No. Observations:                1393   AIC:                            -9857.
# Df Residuals:                    1386   BIC:                            -9820.
# Df Model:                           6
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -0.0003      0.000     -1.394      0.164      -0.001       0.000
# Dow Jones U.S. Thematic Long Size Total Return Index    -0.3375      0.062     -5.444      0.000      -0.459      -0.216
# S&P 500 ESG Enhanced Value Index (USD) TR               -0.4034      0.096     -4.198      0.000      -0.592      -0.215
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR         0.1570      0.077      2.050      0.041       0.007       0.307
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR          1.5282      0.051     29.947      0.000       1.428       1.628
# S&P 500 Pure Growth (TR)                                -0.2777      0.049     -5.630      0.000      -0.374      -0.181
# S&P 500 Pure Value (TR)                                  0.2375      0.093      2.556      0.011       0.055       0.420
# ==============================================================================
# Omnibus:                      207.669   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              835.002
# Skew:                          -0.666   Prob(JB):                    4.81e-182
# Kurtosis:                       6.551   Cond. No.                         643.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00010222996729335169
# Regularized Prediction Mean Squared Error: 0.0003001251217208785
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    AEP   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     670.5
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          2.67e-322
# Time:                        20:08:40   Log-Likelihood:                 5128.6
# No. Observations:                1393   AIC:                        -1.025e+04
# Df Residuals:                    1388   BIC:                        -1.022e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                 2.481e-05      0.000      0.151      0.880      -0.000       0.000
# Dow Jones U.S. Thematic Long Size Total Return Index    -0.4429      0.045     -9.880      0.000      -0.531      -0.355
# S&P 500 ESG Enhanced Value Index (USD) TR               -0.6781      0.069     -9.890      0.000      -0.813      -0.544
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR          1.6300      0.033     49.235      0.000       1.565       1.695
# S&P 500 Pure Value (TR)                                  0.4374      0.059      7.386      0.000       0.321       0.554
# ==============================================================================
# Omnibus:                       50.685   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.217
# Skew:                          -0.237   Prob(JB):                     1.05e-22
# Kurtosis:                       4.232   Cond. No.                         517.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00020737038378939893
# Regularized Prediction Mean Squared Error: 0.0003592094436248251
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   GOOG   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          1.04e-215
# Time:                        20:08:40   Log-Likelihood:                 4394.6
# No. Observations:                1393   AIC:                            -8777.
# Df Residuals:                    1387   BIC:                            -8746.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                                0.0001      0.000      0.512      0.609      -0.000       0.001
# S&P 500 ESG Enhanced Value Index (USD) TR            0.5122      0.145      3.531      0.000       0.228       0.797
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR    -0.5151      0.066     -7.750      0.000      -0.645      -0.385
# S&P 500 Low Rate-Sensitivity Index (USD) TR         -1.2618      0.141     -8.966      0.000      -1.538      -0.986
# S&P 500 Quality - Lowest Quintile Index TR           1.0475      0.118      8.877      0.000       0.816       1.279
# S&P 500 Pure Growth (TR)                             1.1474      0.080     14.284      0.000       0.990       1.305
# ==============================================================================
# Omnibus:                      911.139   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            83576.341
# Skew:                           2.198   Prob(JB):                         0.00
# Kurtosis:                      40.691   Cond. No.                         670.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00023150599456853876
# Regularized Prediction Mean Squared Error: 0.0006126798705606159
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    XOM   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     221.5
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          9.17e-221
# Time:                        20:08:40   Log-Likelihood:                 4738.1
# No. Observations:                1393   AIC:                            -9460.
# Df Residuals:                    1385   BIC:                            -9418.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -0.0005      0.000     -2.266      0.024      -0.001   -6.62e-05
# Dow Jones U.S. Thematic Long Size Total Return Index    -0.3261      0.079     -4.152      0.000      -0.480      -0.172
# S&P 500 ESG Quality Index (USD) TR                       1.5090      0.127     11.856      0.000       1.259       1.759
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR         0.3249      0.077      4.220      0.000       0.174       0.476
# S&P 500 Volatility - Highest Quintile Index TR           0.4325      0.055      7.925      0.000       0.325       0.539
# S&P 500 Low Rate-Sensitivity Index (USD) TR             -0.9886      0.311     -3.182      0.001      -1.598      -0.379
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR          0.5910      0.148      3.990      0.000       0.300       0.882
# S&P 500 Pure Growth (TR)                                -0.6440      0.069     -9.302      0.000      -0.780      -0.508
# ==============================================================================
# Omnibus:                       71.261   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              252.019
# Skew:                          -0.034   Prob(JB):                     1.88e-55
# Kurtosis:                       5.083   Cond. No.                     1.62e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.000342666094019223
# Regularized Prediction Mean Squared Error: 0.001738578935836549
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    LNC   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     787.4
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        20:08:40   Log-Likelihood:                 4593.2
# No. Observations:                1393   AIC:                            -9174.
# Df Residuals:                    1387   BIC:                            -9143.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                               -0.0001      0.000     -0.417      0.677      -0.001       0.000
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     1.4208      0.097     14.685      0.000       1.231       1.611
# S&P 500 Volatility - Highest Quintile Index TR      -0.9098      0.057    -15.965      0.000      -1.022      -0.798
# S&P 500 Low Rate-Sensitivity Index (USD) TR          0.9970      0.193      5.178      0.000       0.619       1.375
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR     -0.8742      0.127     -6.862      0.000      -1.124      -0.624
# S&P 500 Pure Value (TR)                              0.5548      0.100      5.549      0.000       0.359       0.751
# ==============================================================================
# Omnibus:                      234.090   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2244.576
# Skew:                          -0.471   Prob(JB):                         0.00
# Kurtosis:                       9.147   Cond. No.                         973.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00018547072825166877
# Regularized Prediction Mean Squared Error: 0.0005833241350037871
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   NTRS   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     702.1
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        20:08:40   Log-Likelihood:                 4730.5
# No. Observations:                1393   AIC:                            -9451.
# Df Residuals:                    1388   BIC:                            -9425.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                            -9.012e-06      0.000     -0.041      0.967      -0.000       0.000
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     1.4471      0.060     24.267      0.000       1.330       1.564
# S&P 500 Volatility - Highest Quintile Index TR      -0.7621      0.050    -15.217      0.000      -0.860      -0.664
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR     -0.1087      0.049     -2.240      0.025      -0.204      -0.014
# S&P 500 Quality - Lowest Quintile Index TR           0.3938      0.069      5.697      0.000       0.258       0.529
# ==============================================================================
# Omnibus:                      514.420   Durbin-Watson:                   1.834
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16202.812
# Skew:                          -1.074   Prob(JB):                         0.00
# Kurtosis:                      19.569   Cond. No.                         406.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00014440790332345446
# Regularized Prediction Mean Squared Error: 0.0006676062993689223
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    USB   R-squared:                       0.699
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     459.5
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):               0.00
# Time:                        20:08:40   Log-Likelihood:                 5135.5
# No. Observations:                1393   AIC:                        -1.025e+04
# Df Residuals:                    1385   BIC:                        -1.021e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                               -0.0001      0.000     -0.622      0.534      -0.000       0.000
# S&P 500 ESG Quality Index (USD) TR                   0.2996      0.092      3.260      0.001       0.119       0.480
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     0.9435      0.056     16.831      0.000       0.833       1.053
# S&P 500 Volatility - Highest Quintile Index TR      -0.6440      0.041    -15.834      0.000      -0.724      -0.564
# S&P 500 Low Rate-Sensitivity Index (USD) TR          0.7405      0.225      3.292      0.001       0.299       1.182
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR     -0.3530      0.110     -3.211      0.001      -0.569      -0.137
# S&P 500 Quality - Lowest Quintile Index TR           0.4059      0.069      5.876      0.000       0.270       0.541
# S&P 500 Pure Growth (TR)                            -0.4690      0.055     -8.566      0.000      -0.576      -0.362
# ==============================================================================
# Omnibus:                      110.002   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              502.778
# Skew:                           0.204   Prob(JB):                    6.66e-110
# Kurtosis:                       5.915   Cond. No.                     1.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 9.878581253142034e-05
# Regularized Prediction Mean Squared Error: 0.0003983836768969755
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    AME   R-squared:                       0.626
# Model:                            OLS   Adj. R-squared:                  0.623
# Method:                 Least Squares   F-statistic:                     256.7
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          1.41e-287
# Time:                        20:08:40   Log-Likelihood:                 4833.9
# No. Observations:                1393   AIC:                            -9648.
# Df Residuals:                    1383   BIC:                            -9595.
# Df Model:                           9
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                            -3.821e-05      0.000     -0.188      0.851      -0.000       0.000
# S&P 500 ESG Quality Index (USD) TR                   0.6251      0.132      4.734      0.000       0.366       0.884
# S&P 500 ESG Enhanced Value Index (USD) TR           -0.5527      0.142     -3.901      0.000      -0.831      -0.275
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR     0.4813      0.084      5.736      0.000       0.317       0.646
# S&P 500 Volatility - Highest Quintile Index TR      -0.2381      0.051     -4.634      0.000      -0.339      -0.137
# S&P 500 Low Rate-Sensitivity Index (USD) TR          2.8159      0.319      8.819      0.000       2.190       3.442
# S&P 500 Low Rate-Sensitivity 100 Index (USD) TR     -1.2429      0.145     -8.549      0.000      -1.528      -0.958
# S&P 500 Quality - Lowest Quintile Index TR          -0.4022      0.086     -4.651      0.000      -0.572      -0.233
# S&P 500 Pure Growth (TR)                            -0.2325      0.084     -2.755      0.006      -0.398      -0.067
# S&P 500 Pure Value (TR)                             -0.2105      0.106     -1.980      0.048      -0.419      -0.002
# ==============================================================================
# Omnibus:                      253.049   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4589.274
# Skew:                           0.263   Prob(JB):                         0.00
# Kurtosis:                      11.877   Cond. No.                     1.76e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Final alpha value used: 0.01
# Prediction Mean Squared Error: 0.00020596582262960645
# Regularized Prediction Mean Squared Error: 0.0003626480053954605
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  GOOGL   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                     301.0
# Date:                Mon, 20 Dec 2021   Prob (F-statistic):          2.41e-218
# Time:                        20:08:40   Log-Likelihood:                 4408.3
# No. Observations:                1393   AIC:                            -8805.
# Df Residuals:                    1387   BIC:                            -8773.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                                0.0001      0.000      0.480      0.631      -0.000       0.001
# S&P 500 ESG Enhanced Value Index (USD) TR            0.4890      0.144      3.404      0.001       0.207       0.771
# S&P 500 High Rate-Sensitivity 100 Index (USD) TR    -0.5328      0.066     -8.096      0.000      -0.662      -0.404
# S&P 500 Low Rate-Sensitivity Index (USD) TR         -1.2039      0.139     -8.640      0.000      -1.477      -0.931
# S&P 500 Quality - Lowest Quintile Index TR           1.0170      0.117      8.703      0.000       0.788       1.246
# S&P 500 Pure Growth (TR)                             1.1667      0.080     14.667      0.000       1.011       1.323
# ==============================================================================
# Omnibus:                      939.686   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            96192.088
# Skew:                           2.280   Prob(JB):                         0.00
# Kurtosis:                      43.454   Cond. No.                         670.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# {'S&P 500 Pure Value (TR)': {'AVB', 'AEP', 'D', 'AME', 'LNC'}, 'S&P 500 Pure Growth (TR)': {'GOOGL', 'USB', 'GOOG', 'XOM'}, 'S&P 500 Quality - Lowest Quintile Index TR': {'NTRS'}}
